# %% [markdown]
# # FDA Analysis
#
# This notebook contains the analysis of FDA approved drugs for the KGs.

# %%
import os
import json
import pandas as pd
from tqdm import tqdm

from pyenveda.chemicals import get_chemical_by_name

from utils import get_disease_map, KG_DATA_PATH, DATA_DIR, get_chem_map, create_venn_diagram

# %% [markdown]
# # Load mapping dicts

# %%
disease_dict = get_disease_map()
chemical_dict = get_chem_map()

# %% [markdown]
# # Load and normalize FDA file

# %%
df = pd.read_csv(
    os.path.join(DATA_DIR, 'gold-standard', 'drug_indication_df.tsv'),
    sep='\t',
    dtype=str
)

df['indication'] = df['indication'].apply(lambda x: f'umls:{x}')

pubchem = []
mondo_id = []
for row in tqdm(df[['drug', 'drug_name', 'indication']].values, desc='Normalizing chemicals'):
    drug_idx, drug_name, mesh_id = row
    pubchem_id = chemical_dict.get(drug_idx)
    
    if not pubchem_id:
        pubchem_id = get_chemical_by_name(drug_name)
        
    pubchem.append(pubchem_id)
    
    mondo_id.append(disease_dict.get(mesh_id))
    
    
df['pubchem_id'] = pubchem
df['mondo_id'] = mondo_id
df
# Out:
# Normalizing chemicals: 100%|██████████| 5926/5926 [01:28<00:00, 66.86it/s]
#          drug            drug_name     indication  \
# 0     DB00001            Lepirudin  umls:C0040038
# 1     DB00001            Lepirudin  umls:C0002965
# 2     DB00001            Lepirudin  umls:C0040053
# 3     DB00002            Cetuximab  umls:C0007102
# 4     DB00002            Cetuximab  umls:C1168401
# ...       ...                  ...            ...
# 5921      NaN          zotarolimus  umls:C0948480
# 5922  DB09225             zotepine  umls:C0036341
# 5923  DB01624       zuclopenthixol  umls:C0036341
# 5924  DB01624       zuclopenthixol  umls:C0005586
# 5925      NaN  5-hydroxytryptophan  umls:C0917801
#
#                                     indication_name  \
# 0                                   Thromboembolism
# 1                                  Angina, Unstable
# 2                                        thrombosis
# 3                          Malignant Tumor Of Colon
# 4     head and neck squamous cell carcinoma (HNSCC)
# ...                                             ...
# 5921                     coronary artery restenosis
# 5922                                  schizophrenia
# 5923                                  schizophrenia
# 5924                               bipolar disorder
# 5925                                  Sleeplessness
#
#                       pubchem_id       mondo_id
# 0     pubchem.compound:118856773           None
# 1     pubchem.compound:118856773  mondo:0006805
# 2     pubchem.compound:118856773  mondo:0000831
# 3                           None  mondo:0021063
# 4                           None  mondo:0010150
# ...                          ...            ...
# 5921    pubchem.compound:9876378  mondo:0005355
# 5922                        5736  mondo:0005090
# 5923                     5311507  mondo:0005090
# 5924                     5311507  mondo:0004985
# 5925        pubchem.compound:144  mondo:0013600
#
# [5926 rows x 6 columns]

# %%
df.dropna(subset=['pubchem_id', 'mondo_id'], how='any', inplace=True)
df
# Out:
#          drug            drug_name     indication             indication_name  \
# 1     DB00001            Lepirudin  umls:C0002965            Angina, Unstable
# 2     DB00001            Lepirudin  umls:C0040053                  thrombosis
# 45    DB00010           Sermorelin  umls:C0013338          Pituitary Dwarfism
# 46    DB00010           Sermorelin  umls:C0343755        Hiv Wasting Syndrome
# 47    DB00010           Sermorelin  umls:C0021359                 infertility
# ...       ...                  ...            ...                         ...
# 5921      NaN          zotarolimus  umls:C0948480  coronary artery restenosis
# 5922  DB09225             zotepine  umls:C0036341               schizophrenia
# 5923  DB01624       zuclopenthixol  umls:C0036341               schizophrenia
# 5924  DB01624       zuclopenthixol  umls:C0005586            bipolar disorder
# 5925      NaN  5-hydroxytryptophan  umls:C0917801               Sleeplessness
#
#                       pubchem_id       mondo_id
# 1     pubchem.compound:118856773  mondo:0006805
# 2     pubchem.compound:118856773  mondo:0000831
# 45     pubchem.compound:16129620  mondo:0006909
# 46     pubchem.compound:16129620  mondo:0005797
# 47     pubchem.compound:16129620  mondo:0005047
# ...                          ...            ...
# 5921    pubchem.compound:9876378  mondo:0005355
# 5922                        5736  mondo:0005090
# 5923                     5311507  mondo:0005090
# 5924                     5311507  mondo:0004985
# 5925        pubchem.compound:144  mondo:0013600
#
# [4237 rows x 6 columns]

# %% [markdown]
# # Save pairs which overlap with KG

# %%
with open(os.path.join(KG_DATA_PATH, 'normalized', 'data.json')) as f:
    data_dict = json.load(f)

# %%
pair_overlaps = set()

for source, target in tqdm(df[['pubchem_id', 'mondo_id']].values):
    if source in data_dict['chemicals'] and target in data_dict['diseases']:
        pair_overlaps.add((source, target))
        
len(pair_overlaps)
# Out:
# 100%|██████████| 4237/4237 [00:00<00:00, 13004.79it/s]
# 23

# %%
with open(os.path.join(DATA_DIR, 'gold-standard', 'fda_pairs.json'), 'w') as f:
    json.dump(list(pair_overlaps), f, ensure_ascii=True, indent=2)
